# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data
#
# Info about this data set: https://fred.stlouisfed.org/series/TRFVOLUSM227NFWA

# %%
df = pd.read_csv('Miles_Traveled.csv',index_col='DATE',parse_dates=True)
df.index.freq = 'MS'

# %%
df.head()
# Out:
#             TRFVOLUSM227NFWA
# DATE
# 1970-01-01           80173.0
# 1970-02-01           77442.0
# 1970-03-01           90223.0
# 1970-04-01           89956.0
# 1970-05-01           97972.0

# %% [markdown]
# **Task: Change the column names to Value**

# %%
df.columns = ['Value']

# %% [markdown]
# **TASK: Plot out the time series**

# %%
df.plot(figsize=(12,8))

# %% [markdown]
# **TASK: Perform a Seasonal Decomposition on the model and plot out the ETS components**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['Value'])
results.observed.plot(figsize=(12,2))

# %%
results.trend.plot(figsize=(12,2))

# %%
results.seasonal.plot(figsize=(12,2))

# %%
results.resid.plot(figsize=(12,2))

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# **TASK: Figure out the length of the data set**

# %%
len(df)
# Out:
# 588

# %%
train_len = len(df)-12

# %% [markdown]
# **TASK: Split the data into a train/test split where the test set is the last 12 months of data.**

# %%
train = df.iloc[:train_len]
test = df.iloc[train_len:]

# %%
len(test)
# Out:
# 12

# %% [markdown]
# ## Scale Data

# %% [markdown]
# **TASK: Use a MinMaxScaler to scale the train and test sets into scaled versions.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# IGNORE WARNING ITS JUST CONVERTING TO FLOATS
# WE ONLY FIT TO TRAININ DATA, OTHERWISE WE ARE CHEATING ASSUMING INFO ABOUT TEST SET
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# # Time Series Generator
#
# **TASK: Create a TimeSeriesGenerator object based off the scaled_train data. The n_input is up to you, but at a minimum it should be at least 12.**

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
n_input = 24
n_features=1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %% [markdown]
# ### Create the Model
#
# **TASK: Create a Keras Sequential Model with as many LSTAM units you want and a final Dense Layer.**

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(150, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 151
# =================================================================
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **TASK: Fit the model to the generator**

# %%
# fit model
model.fit_generator(generator,epochs=50)
# Out:
# Epoch 1/50
# 552/552 [==============================] - 21s 38ms/step - loss: 0.0163
# Epoch 2/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0072
# Epoch 3/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0057
# Epoch 4/50
# 552/552 [==============================] - 20s 35ms/step - loss: 0.0058
# Epoch 5/50
# 552/552 [==============================] - 20s 35ms/step - loss: 0.0042
# Epoch 6/50
# 552/552 [==============================] - 19s 35ms/step - loss: 0.0033
# Epoch 7/50
# 552/552 [==============================] - 20s 35ms/step - loss: 0.0027
# Epoch 8/50
# 552/552 [==============================] - 20s 35ms/step - loss: 0.0022
# Epoch 9/50
# 552/552 [==============================] - 19s 35ms/step - loss: 0.0017
# Epoch 10/50
# 552/552 [==============================] - 20s 35ms/step - loss: 0.0016
# Epoch 11/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0013
# Epoch 12/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0011
# Epoch 13/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0011
# Epoch 14/50
# 552/552 [==============================] - 21s 38ms/step - loss: 0.0010
# Epoch 15/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0011
# Epoch 16/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0012
# Epoch 17/50
# 552/552 [==============================] - 20s 36ms/step - loss: 0.0010
# Epoch 18/50
# 552/552 [==============================] - 20s 37ms/step - loss: 9.8025e-04
# Epoch 19/50
# 552/552 [==============================] - 20s 36ms/step - loss: 9.2641e-04
# Epoch 20/50
# 552/552 [==============================] - 20s 36ms/step - loss: 9.6795e-04
# Epoch 21/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.9176e-04
# Epoch 22/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.9238e-04
# Epoch 23/50
# 552/552 [==============================] - 20s 37ms/step - loss: 8.9091e-04
# Epoch 24/50
# 552/552 [==============================] - 20s 37ms/step - loss: 9.4137e-04
# Epoch 25/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.4777e-04
# Epoch 26/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.7317e-04
# Epoch 27/50
# 552/552 [==============================] - 19s 35ms/step - loss: 8.5688e-04
# Epoch 28/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.7694e-04
# Epoch 29/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.1676e-04
# Epoch 30/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.2259e-04
# Epoch 31/50
# 552/552 [==============================] - 20s 36ms/step - loss: 8.0103e-04
# Epoch 32/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.8475e-04
# Epoch 33/50
# 552/552 [==============================] - 20s 35ms/step - loss: 7.9061e-04
# Epoch 34/50
# 552/552 [==============================] - 21s 37ms/step - loss: 7.1995e-04
# Epoch 35/50
# 552/552 [==============================] - 21s 38ms/step - loss: 8.2296e-04
# Epoch 36/50
# 552/552 [==============================] - 20s 37ms/step - loss: 8.3990e-04
# Epoch 37/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.4944e-04
# Epoch 38/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.1006e-04
# Epoch 39/50
# 552/552 [==============================] - 20s 37ms/step - loss: 7.4026e-04
# Epoch 40/50
# 552/552 [==============================] - 21s 38ms/step - loss: 7.5373e-04
# Epoch 41/50
# 552/552 [==============================] - 21s 38ms/step - loss: 7.5036e-04
# Epoch 42/50
# 552/552 [==============================] - 20s 35ms/step - loss: 7.5042e-04
# Epoch 43/50
# 552/552 [==============================] - 20s 36ms/step - loss: 6.9256e-04
# Epoch 44/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.2535e-04
# Epoch 45/50
# 552/552 [==============================] - 20s 36ms/step - loss: 6.8955e-04
# Epoch 46/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.2602e-04
# Epoch 47/50
# 552/552 [==============================] - 20s 36ms/step - loss: 7.1390e-04
# Epoch 48/50
# 552/552 [==============================] - 19s 35ms/step - loss: 7.0956e-04
# Epoch 49/50
# 552/552 [==============================] - 19s 35ms/step - loss: 6.6356e-04
# Epoch 50/50
# 552/552 [==============================] - 19s 35ms/step - loss: 6.5682e-04

# %% [markdown]
# **TASK: Plot the history of the loss that occured during training.**

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %% [markdown]
# ## Evaluate on Test Data
#
# **TASK: Based on your test data and input size, create an appropriate;y sized "first evaluation batch" like we did in the lecture.**

# %%
first_eval_batch = scaled_train[-12:]

# %%
first_eval_batch
# Out:
# array([[0.79630397],
#        [0.71226435],
#        [0.90477416],
#        [0.93121043],
#        [0.98386382],
#        [0.96757519],
#        [1.        ],
#        [0.9801859 ],
#        [0.8824684 ],
#        [0.95995255],
#        [0.85883345],
#        [0.90086755]])

# %%
first_eval_batch = first_eval_batch.reshape((1, 12, n_features))

# %% [markdown]
# **TASK: Generate predictions into the same time stamps as the test set**

# %%
# CODE HERE

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %% [markdown]
# ## Inverse Transformations and Compare
#
# **TASK: Inverse Transform your new forecasted predictions.**

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[244790.4583751 ],
#        [233844.90710074],
#        [270457.81608635],
#        [272201.29687929],
#        [279289.6588499 ],
#        [279346.60926121],
#        [286210.98546427],
#        [281885.08126384],
#        [268614.50942963],
#        [275487.78100669],
#        [258639.72996229],
#        [262481.15531212]])

# %% [markdown]
# **TASK: Create a new dataframe that has both the original test values and your predictions for them.**

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
# Out:
# C:\Users\Marcial\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test
# Out:
#                Value    Predictions
# DATE
# 2018-01-01  245695.0  244790.458375
# 2018-02-01  226660.0  233844.907101
# 2018-03-01  268480.0  270457.816086
# 2018-04-01  272475.0  272201.296879
# 2018-05-01  286164.0  279289.658850
# 2018-06-01  280877.0  279346.609261
# 2018-07-01  288145.0  286210.985464
# 2018-08-01  286608.0  281885.081264
# 2018-09-01  260595.0  268614.509430
# 2018-10-01  282174.0  275487.781007
# 2018-11-01  258590.0  258639.729962
# 2018-12-01  268413.0  262481.155312

# %% [markdown]
# **TASK: Plot out the test set against your own predicted values.**

# %%
test.plot(figsize=(12,8))

# %% [markdown]
# # Saving Models
#
# **TASK: Optional, Save your model!**

# %%
model.save('solutions_model.h5')
